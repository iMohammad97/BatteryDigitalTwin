# %%
# !rm -rf BatteryDigitalTwin

# %%
# !git clone https://github.com/iMohammad97/BatteryDigitalTwin.git
# Out:
# Cloning into 'BatteryDigitalTwin'...
# remote: Enumerating objects: 3614, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 3614 (delta 10), reused 31 (delta 9), pack-reused 3580 (from 2)
# Receiving objects: 100% (3614/3614), 206.48 MiB | 26.26 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# Updating files: 100% (3510/3510), done.

# %%
# %cd BatteryDigitalTwin
# Out:
# /kaggle/working/BatteryDigitalTwin/BatteryDigitalTwin

# %%
# !find . -maxdepth 2 | sed -e 's/^/  /g'
# Out:
#   .
#   ./utils
#   ./utils/util.py
#   ./utils/__pycache__
#   ./utils/__init__.py
#   ./results analysis
#   ./results analysis/utils
#   ./results analysis/XJTU results PINN.py
#   ./results analysis/TJU results PINN.py
#   ./results analysis/TJU results SPINN.py
#   ./results analysis/Comparision results.py
#   ./results analysis/XJTU results SPINN.py
#   ./dataloader
#   ./dataloader/dataloader.py
#   ./dataloader/dataloaderForSoc.py
#   ./dataloader/__pycache__
#   ./dataloader/preprocess_nasa.ipynb
#   ./dataloader/__init__.py
#   ./Model
#   ./Model/AttSPINN.py
#   ./Model/__pycache__
#   ./README.md
#   ./Experiments
#   ./Experiments/main_XJTU_AttSPINN.py
#   ./Experiments/main_NASA_AttSPINN.py
#   ./Experiments/main_TJU_AttSPINN.py
#   ./Experiments/__pycache__
#   ./data
#   ./data/XJTU data
#   ./data/NASA data
#   ./data/HUST data
#   ./data/TJU data
#   ./data/MIT data
#   ./.git
#   ./.git/hooks
#   ./.git/info
#   ./.git/packed-refs
#   ./.git/description
# ...

# %%
# !python3 -m Experiments.main_NASA_AttSPINN \
    --data_root "data/NASA data" \
    --save_root "results/NASA" \
    --epochs 500
# Out:
# Using cuda
#
# --- Experiment 1 ---
# Loading all NASA data...
# 2025-06-29 09:33 - function:_save_args - INFO - Args:
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	data_root:data/NASA data
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	save_root:results/NASA
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	batch_size:256
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	normalization_method:min-max
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	epochs:200
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	warmup_epochs:30
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	warmup_lr:0.002
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	lr:0.01
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	final_lr:0.0002
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	lr_F:0.001
# 2025-06-29 09:33 - function:_save_args - CRITICAL - 	alpha:0.08549401305482651
# ...
